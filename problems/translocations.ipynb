# %% [markdown]
# # Translocation questions
#  In 1999, Neal et al. (Animal Biotechnology 10:153–158) analyzed the chromosome constitution of embryos extracted from female pigs that were heterozygous for a reciprocal translocation between the X chromosome and chromosome 14. These female pigs had all mated with males whose chromosome constitution was normal. Neal et al. examined 38 embryos taken from the female pigs at two weeks of gestation and recorded the following data, which are numbered as three different classes of embryos:
#
# Chromosome constitution of embryo, Number of embryos
#
# Balanced, no translocation	         16
#
# Balanced, translocation	             10
#
# Unbalanced	                         12

# %% [markdown]
# ## Question 1
# Based on the predicted segregation ratios for reciprocal translocation heterozygotes, how many balanced embryos, without translocation, are expected?

# %%
# The expected ratio of embryos from this mating should be: 2 unbalanced : 1 balanced, without translocation : 1 balanced, with translocation. This means that we should expect 1/4 of the embryos or 9.5 to be balanced without a translocated chromosome. 

# answer is 9.5

# %% [markdown]
# ## Chi Square analysis
# Using chi-square analysis, test the hypothesis that the results conform to the frequencies of embryos expected with typical chromosome segregations in a reciprocal translocation heterozygote. What is your chi-square statistic?
#
# Answer:
# ![image.png](data:image/png;base64,...)

# %%
# answer is 7.05

# %% [markdown]
# ## Question 3
# One of the reasons that you might reject your hypothesis that the results conform to a typical segregation ratio for a reciprocal translocation heterozygote is because there are far fewer unbalanced embryos than expected. Neal et al. found that among the twelve unbalanced embryos, eleven were of one gender and only one of the opposite gender. They examined another set of embryos from this cross at four weeks gestation and found that all unbalanced embryos were of the same gender as the eleven unbalanced two-week embryos from the data set shown above. Which gender is most likely overrepresented in these unbalanced pig embryos?

# %%
# The correct answer is female. Males are hemizygous for the X chromosome, which is one of the chromosomes involved in the translocation. Many of the unbalanced male embryos will lack complete portions of the X chromosome because they would not receive a normal X chromosome from the male parent. Unbalanced, female embryos, on the other hand, would have at least one intact X chromosome received from their male parent. The absence of X-chromosome material in a portion of the unbalanced male embryos would make them more likely to abort earlier in gestation. 

# answer is female

# %% [markdown]
# ## Drosophila with translocations
# A male Drosophila from a wild-type stock is discovered to have only seven chromosomes rather the normal 2n=8. Karyotyping of the fly reveals translocation of one chromosome IV to distal end of a chromosome II – thus accounting for the reduction in chromosome number (see figure to the right).  If this male mates with a female with a normal chromosome composition who is homozygous for the recessive chromosome IV mutation eyeless (ey), what will be the phenotypic ratio of the eyeless flies in the progeny, assuming all chromosome compositions survive?
#
# ![image.png](data:image/png;base64,...)

# %%
# The correct answer is 1/6. Remember that a during meiosis the translocation male will form a trivalent (consisting of chromsomes II and IV) which will separate in to 6 different types of gametes, of which one will be just chromsome II and thus lack the dominant wildtype EY allele. When combined with the normal gamete that carries the ey allele from the female, this one (out of six) zygote will develop into an eyeless mutant. Will it have a normal number of chromosomes? 

# answer is 1/6

# %% [markdown]
# # Context for translocation questions 9 and 10: inhertance of translocations
# In 1984, Martinez-Castro et al. (Cytogenetics and Cell Genetics 38:310-312) published a pedigree of a family in which two first cousins had married. They had six children three who were homozygous for t(13q;14q), two who were heterozygous for t(13q;14q), and one with a normal karyotype.

# %% [markdown]
# ## Question 9
# Should there be a loss of fertility in the three homozygous t(13q;14q) offspring?

# %%
# The correct answer is no. Only translocation heterozygotes will produce unbalanced gametes, which will affect fertility.  Homozygous individuals, either for the translocation or not will produce only balanced games. 

# answer is no

# %% [markdown]
# ## Question 10
# Calculate the probability of this particular outcome for this family (three translocation homozygotes, two translocation heterozygotes, and one normal karyotype). Assume that unbalanced gametes are viable.

# %%
# The correct answer is 0.008. Note that this problem seems like a traditional binomial, but there are three outcomes, specifically: homozygous for the translocation, heterozygous and homozygous wild-type (normal karyotype). We use the same idea of a binomial, but we need to expand the equation to accommodate the three possible outcomes. This new equation is called a "trinomial": 
# P = (n!/x!y!z!)(pxqyrz) Where z is the third possibility and r is the probability of that outcome. 

# answer is 0.008.

# %% [markdown]
# # TA review question:
#
# Who has fertility issues? (select as many as apply) (answer is B and D)
#
# a.	Translocation homozygotes
#
# b.	Translocation heterozygotes
#
# c.	Inversion homozygotes
#
# d.	Inversion heterozygotes

# %% [markdown]
# # TA review question:
# Assuming all gametes survive, how many embryos will be balanced if one of the parents is a(n)…
#
# a.	Robertsonian translocation heterozygote? (answer is 1/3)
#
# b.	Reciprocal translocation homozygote? (all)
#
# c.	Reciprocal translocation heterozygote? (1/2)

# %% [markdown]
# # TA review question: robertsonian translocation
#
# How many gametes can an individual heterozygous for a Robertsonian translocation create?
#
# a.	2
#
# b.	4
#
# c.	6 <--- correct answer
#
# d.	8
#
# e.	0
