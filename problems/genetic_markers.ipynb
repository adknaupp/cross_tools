# %% [markdown]
# ## TA review question
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# answer to A is 10%, answer to B is 0.12%

# %% [markdown]
# ## TA review question
# ![image.png](data:image/png;base64,...)
